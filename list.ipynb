# %%
# It's Mutable i.e changeable
# It can store any datatype

# %% [markdown]
# # List operations

# %%
#Concatenation of list
l1,l2=[1,2,3],[4,5,6]
list=l1+l2
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Replication of list
l=[1]
print(l*3)
# Out:
# [1, 1, 1]

# %%
l1=[1,2,3]
l1[0],l1[2]
# Out:
# (1, 3)

# %%
#Updating elements in the list
l=[1,2,3,4,5,6,7]
print(l)
l[0]='0th element is updated'
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# ['0th element is updated', 2, 3, 4, 5, 6, 7]

# %%
# Appending elements in the list
# append() method add the element at the end of the existing element
l=['hello',1,2,0.6]
print(l)
l.append('element is added at end of list with help of append() method')
print(l)
l.append([11,22])
print(l)
# Out:
# ['hello', 1, 2, 0.6]
# ['hello', 1, 2, 0.6, 'element is added at end of list with help of append() method']
# ['hello', 1, 2, 0.6, 'element is added at end of list with help of append() method', [11, 22]]

# %%
l=[]
l.append('hello')
print(l)
# Out:
# ['hello']

# %%
#Deleting elements from the list
# del statement can be use to delete an element from the list
l=[1,2,3]
l1,l3=['hi',0.5,4],['hello']
del l[0]
print(l) 
del l1[1:]
print(l1)
del l3
# Out:
# [2, 3]
# ['hi']

# %% [markdown]
# # Various functions of list

# %%
#min(list) function
l=[1,2,4,55,6,3]
print(f'Minimum value in the list is {min(l)}')
#max(list)function
print(f'Maximum value in the list is {max(l)}')
#len() fuction
print(f'Length of list is {len(l)}' )
# Out:
# Minimum value in the list is 1
# Maximum value in the list is 55
# Length of list is 6

# %% [markdown]
# # Various methods of list

# %%
l=[1,2,4,55,6,35]
print(l.index(55))#Returns the index of the first-occurance of the element in the list. if index is found otherwise returns an error
popped_element=l.pop()#Remove and return item at index (default last).
print(popped_element)
print(l.pop(0))# it takes index inside pop() method and remove that element present at provided index
# Out:
# 3
# 35
# 1

# %%
l=[1,2,4,55,6,35]
print(l)
l.insert(0,'zero')#Signature: l.insert(index, object, /)
print(l)          #Docstring: Insert object before index.
# Out:
# [1, 2, 4, 55, 6, 35]
# ['zero', 1, 2, 4, 55, 6, 35]

# %%
l1=['list1',1]
l2=['list2',2]
l3=['list3',3]
l1.extend(l2)# l1.extend(iterable, /)
l2.extend('hello sir')
l3.extend(l2)
print(f'List 1 :--->{l1}')
print(f'List 2 :--->{l2}')
print(f'List 3 :--->{l3}')
# Out:
# List 1 :--->['list1', 1, 'list2', 2]
# List 2 :--->['list2', 2, 'h', 'e', 'l', 'l', 'o', ' ', 's', 'i', 'r']
# List 3 :--->['list3', 3, 'list2', 2, 'h', 'e', 'l', 'l', 'o', ' ', 's', 'i', 'r']

# %%
l=[]
l.extend('hello')
l
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
#l2.remove(value, /)
#Remove first occurrence of value,if element not present then it will return error.
l2=['zero', 1, 2, 4, 55, 6, 35]
l2.remove('zero')
print(l2)
# Out:
# [1, 2, 4, 55, 6, 35]

# %%
l2=[1,2,3,4,5,6,7,8]
l2.reverse()#It is only defined for list
print(l2)
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
str='hello'
x=reversed(str)
print(type(x))
print(*x)#Here * means that unpacking of iterables/iterators like list,tuple etc...
# Out:
# <class 'reversed'>
# o l l e h

# %%
l2,l3=[1, 2, 4, 55, 6, 35],[4,2,3,46,45]
l2.sort()
l3.sort(reverse=True)# now it is sorting in decreasing order if True and only applicable for homogenious element not for hetrogenious element 
print(l2,l3,sep='\n')
# Out:
# [1, 2, 4, 6, 35, 55]
# [46, 45, 4, 3, 2]

# %%
hetro_ele = [3,2,1,'banana','apple'] 
# hetro_ele.sort() # '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# - .sort() vs sorted() , .sort is list specific method which does the sorting without creating the new object but while in case of sorted it created a new object in the memory.
# - and l.sort() returns None while sorted returns the object on which it is applied

# %%
l = [32,2,4] 
l.sort 
l
# Out:
# [32, 2, 4]

# %%
l = [32,2,4] 
sorted(l)
# Out:
# [2, 4, 32]

# %% [markdown]
# ## 10th,February 2020

# %% [markdown]
# ## Type Casting

# %%
detail=(1,)
new_data=list(detail)
print(type(detail),type(new_data))
# Out:
# <class 'tuple'> <class 'list'>

# %%
print(type(type('hello')))#<----------------------------
# Out:
# <class 'type'>

# %%
#When we use string slicing then it return a list with a value

# %%
# 06:15 to 07:15

# %%
# If elements are repeating then first occurence will get removed
marks=[90,90,60,90,55]
marks.remove(90)
print(marks)
# Out:
# [90, 60, 90, 55]

# %%
# Shallow copy():
marks=[90,90,60,90,55]
cmarks=marks.copy() # Shallow Copy and it's only applicable on the mutable datatypes
cmarks.remove(55)
print(cmarks)
print(marks)
# Out:
# [90, 90, 60, 90]
# [90, 90, 60, 90, 55]

# %%
# Deep Copy
dmarks=marks# Assigning is called deepcopy
dmarks.remove(60)
print(dmarks)
print(marks)
# Out:
# [90, 90, 90, 55]
# [90, 90, 90, 55]

# %%
# Empty the list: clear()
marks.clear()
print(marks)
# Out:
# []

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Delete object from memory:
del marks #del is destructor 
# print(marks)

# %%
l1=[1,2,4,5,6,35]
l1.insert(1,55)
l1
# Out:
# [1, 55, 2, 4, 5, 6, 35]

# %%
l = [1,2,4,5,6,35]
l
# Out:
# [1, 2, 4, 5, 6, 35]

# %%
l.insert(100,777)
print(l) # if index is more than the maximum index of the list then it will insert the element at the last in the list. 
l.insert(-100,777)
print(l) # if index is less than the minimum index of the list then it will insert the element at the first position in the list.
# Out:
# [1, 2, 4, 5, 6, 35, 777]
# [777, 1, 2, 4, 5, 6, 35, 777]

# %%
l1 = [45,'sudh',[2,3,4],4]

# %%
l1
# Out:
# [45, 'sudh', [2, 3, 4], 4]

# %%
l1[::-1]# It does not reverse the original list
# Out:
# [4, [2, 3, 4], 'sudh', 45]

# %%
l1
# Out:
# [45, 'sudh', [2, 3, 4], 4]

# %%
l1.reverse() # It reverse the original list and it does not create the new object in the memory it reverse the element into existing list.

# %%
l1
# Out:
# [4, [2, 3, 4], 'sudh', 45]

# %%
l1 = l1[::-1] # re-assignment changing in the original another way

# %%
l1
# Out:
# [4, [2, 3, 4], 'sudh', 45]

# %%
list_reverseiterator = reversed(l1) # it creates a new iterator object while .reverse() does not create a new object and it is python inbuilt function which applicable for list,tuple,string etc...
print(list_reverseiterator,type(list_reverseiterator))
print(list(list_reverseiterator))
# Out:
# <list_reverseiterator object at 0x7eab9b577250> <class 'list_reverseiterator'>
# [45, 'sudh', [2, 3, 4], 4]

# %%
l2 = [45,23,90,0,3,4,6,7,8,9] 
l2
# Out:
# [45, 23, 90, 0, 3, 4, 6, 7, 8, 9]

# %%
l2.sort() # .sort() works on the similar type of datatype present inside the list

# %%
l2
# Out:
# [0, 3, 4, 6, 7, 8, 9, 23, 45, 90]

# %%
# l1.sort()# It does not work on the different-different type of data inside the list

# %%
l3 = ['v','fd','ev']
l3.sort(reverse=True)

# %%
l3
# Out:
# ['v', 'fd', 'ev']

# %% [markdown]
# - in list order is important and duplicacy

# %% [markdown]
# - **Relational Operators**
#     - This is applicable only element value not on whole list ,pehle first element check krenge uske baad second element ko check karenge aur ye ese hi chalta jayega jbtk decide nhi ho jata ki kuan sa element big hai.
#     - Aur ye same relational operator ka concept string me bhi laagu(applicable) hota hai.

# %%
l1 = [10,20,30] 
l2 = [5,60] 

print(l1 < l2) # False
print(l1 <= l2) # False
print(l1 > l2) # True
print(l1 >= l2) # True
# Out:
# False
# False
# True
# True

# %%
l = [10,20,20,30,10,40,20,60]

print(l.count(10)) # 2 
print(l.count(20)) # 2
print(l.count(50)) # 0 ,because not present in the list
# Out:
# 2
# 3
# 0

# %% [markdown]
# - **aliasing and cloning**

# %%
l1 = [10,20,20,30,10,40,20,60]

l2 = l1 # this is called aliasing ,creating duplicate refrences are called aliasing 
print(l1 is l2) # this will return True 
print(f'id of l1 {id(l1)} ,value of l1 : {l1}',f'id of l2 {id(l2)} ,value of l2 : {l2}',sep='\n') # both ids will be same here  

# and if change in any of list either in l1 or l2 then changes will be reflected to both the list.
# Out:
# True
# id of l1 134561393692224 ,value of l1 : [10, 20, 20, 30, 10, 40, 20, 60]
# id of l2 134561393692224 ,value of l2 : [10, 20, 20, 30, 10, 40, 20, 60]

# %% [markdown]
# - for cloning there are two methods are available
#     - 1. slice method
#     - 2. copy() method
#
# - The process of creating duplicates objects are called cloning.

# %% [markdown]
# slicing cloning

# %%
l1 = [10,20,20,30,10,40,20,60]

l2 = l1[:] # this is called cloning ,creating duplicate objects are called cloning. 
print(l1 is l2) # this will return False 
l2[2] = 7777
print(f'id of l1 {id(l1)} ,value of l1 : {l1}',f'id of l2 {id(l2)} ,value of l2 : {l2}',sep='\n') # both ids will be differ here.

# and if change in any of list either in l1 or l2 then changes will be reflected to only that list.
# Out:
# False
# id of l1 134561422292928 ,value of l1 : [10, 20, 20, 30, 10, 40, 20, 60]
# id of l2 134561396003648 ,value of l2 : [10, 20, 7777, 30, 10, 40, 20, 60]

# %% [markdown]
# copy() cloning

# %%
l1 = [10,20,20,30,10,40,20,60]

l2 = l1.copy() # this is called cloning ,creating duplicate objects are called cloning. 
print(l1 is l2) # this will return False 
l2[2] = 7777
print(f'id of l1 {id(l1)} ,value of l1 : {l1}',f'id of l2 {id(l2)} ,value of l2 : {l2}',sep='\n') # both ids will be differ here.

# and if change in any of list either in l1 or l2 then changes will be reflected to only that list.
# Out:
# False
# id of l1 134561413104448 ,value of l1 : [10, 20, 20, 30, 10, 40, 20, 60]
# id of l2 134561398134912 ,value of l2 : [10, 20, 7777, 30, 10, 40, 20, 60]
