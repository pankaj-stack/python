# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Exception Handling</title>
# </head>
# <body>
#     <h1>Exception Handling</h1>
#     <ul>
#         <li><strong>Syntax Errors:</strong> These are errors in the structure or syntax of the code that prevent the program from running.</li>
#         <li><strong>Runtime Errors:</strong> These errors occur while the program is running and can cause it to crash or behave unexpectedly.</li>
#     </ul>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Syntax Errors</title>
# </head>
# <body>
#     <h1>Syntax Errors</h1>
#     <p>The errors which occur because of invalid syntax are considered as Syntax Errors.</p>
#     <p>Programmers are responsible for correcting these syntax errors. Once all syntax errors are corrected, the program execution can start.</p>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Runtime Errors</title>
# </head>
# <body>
#     <h1>Runtime Errors</h1>
#     <ul>
#         <li>Also known as Exceptions.</li>
#         <li>While executing the program, at runtime if something goes wrong because of end user input, memory problems, programming logic etc, then we will get Runtime Errors.</li>
#         <li>Exception Handling concept applicable for Runtime Errors but not for Syntax Errors.</li>
#     </ul>
# </body>
# </html>

# %% [markdown]
# 2. What is the main objective
# of Exception Handling?
#
# > Itis highly recommended to handle
# exceptions.
#
# > The main objective of exception
# handling is Graceful
# Termination/Normal Termination of the
# application(i.e we should not block our
# resources and we should not miss
# anything)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Python Exception Hierarchy</title>
#     <style>
#         .exception-hierarchy {
#             display: flex;
#             flex-direction: column;
#             align-items: center;
#         }
#         .exception-level {
#             display: flex;
#             justify-content: center;
#             margin: 10px 0;
#         }
#         .exception-box {
#             border: 1px solid black;
#             padding: 10px;
#             margin: 0 5px;
#             text-align: center;
#         }
#     </style>
# </head>
# <body>
#     <div class="exception-hierarchy">
#         <div class="exception-level">
#             <div class="exception-box">BaseException</div>
#         </div>
#         <div class="exception-level">
#             <div class="exception-box">Exception</div>
#             <div class="exception-box">SystemExit</div>
#             <div class="exception-box">GeneratorExit</div>
#             <div class="exception-box">KeyboardInterrupt</div>
#         </div>
#         <div class="exception-level">
#             <div class="exception-box">AttributeError</div>
#             <div class="exception-box">ArithmeticError</div>
#             <div class="exception-box">EOFError</div>
#             <div class="exception-box">NameError</div>
#             <div class="exception-box">LookupError</div>
#             <div class="exception-box">OSError</div>
#             <div class="exception-box">TypeError</div>
#             <div class="exception-box">ValueError</div>
#         </div>
#         <div class="exception-level">
#             <div class="exception-box">ZeroDivisionError</div>
#             <div class="exception-box">FloatingPointError</div>
#             <div class="exception-box">OverflowError</div>
#             <div class="exception-box">IndexError</div>
#             <div class="exception-box">KeyError</div>
#             <div class="exception-box">FileNotFoundError</div>
#             <div class="exception-box">InterruptedError</div>
#             <div class="exception-box">PermissionError</div>
#             <div class="exception-box">TimeoutError</div>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Python's Exception Hierarchy</title>
# </head>
# <body>
#     <h1>Python's Exception Hierarchy</h1>
#     <p>Every Exception in Python is a class.</p>
#     <p>All exception classes are child classes of BaseException either directly or indirectly.</p>
#     <p>Hence BaseException acts as root for Python Exception Hierarchy.</p>
#     <p>Being a programmer, most of the times, we have to concentrate/handle Exception and its child classes.</p>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Control flow in try-except</title>
# </head>
# <body>
#     <h1>Control flow in try-except</h1>
#     <ol>
#         <li>Within the try block, if an exception is raised at any point, the rest of the try block won’t be executed even if we handle that exception. Therefore, we should include only the risky code inside the try block, keeping its length as short as possible.</li>
#         <li>In addition to the try block, exceptions may also be raised within the except and finally blocks.</li>
#         <li>If any statement that is not part of the try block raises an exception, it will always result in Abnormal Termination.</li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Finally Block</title>
# </head>
# <body>
#     <h1>finally block</h1>
#     <ol>
#         <li>It is not recommended to place cleanup code (resource deallocation code like closing database connection etc) inside try block, because there is no guarantee for execution of every statement inside try block.</li>
#         <li>It is not recommended to place cleanup code inside except block, because if there is no exception then except block won't be executed.</li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>finally block</title>
# </head>
# <body>
#     <h1>finally block</h1>
#     <pre>
# try:
#     Risky code
# except:
#     Handling Code
# finally:
#     Cleanup code
#     </pre>
#     <p>The specialty of finally block is, it will be executed always irrespective of whether exception raised or not raised and whether exception handled or not handled.</p>
# </body>
# </html>

# %%
try:
    print(10/0) 
except ZeroDivisionError as e:
    print(f'description of exception : {e}')
    print(f'type of exception : {type(e)}')
    print(f'exception class : {e.__class__}')
    print(f'exception class name : {e.__class__.__name__}')
# Out:
# description of exception : division by zero
# type of exception : <class 'ZeroDivisionError'>
# exception class : <class 'ZeroDivisionError'>
# exception class name : ZeroDivisionError

# %%
try:
    print('try')
    print(10/0)
except ValueError: # exception is not handeled so first try block will run and then finally and at end abnoramal termination will be happened 
    print('except')
finally:
    print('finally')
# Out:
# try
# finally
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_241671/2358863779.py in <module>
#       1 try:
#       2     print('try')
# ----> 3     print(10/0)
#       4 except ValueError: # exception is not handeled so first try block will run and then finally and at end abnoramal termination will be happened
#       5     print('except')
#
# ZeroDivisionError: division by zero

# %%
try:
    print(10/0) 
except BaseException as e:
    print(f'description of exception : {e}')
    print(f'type of exception : {type(e)}')
    print(f'exception class : {e.__class__}')
    print(f'exception class name : {e.__class__.__name__}')
# Out:
# description of exception : division by zero
# type of exception : <class 'ZeroDivisionError'>
# exception class : <class 'ZeroDivisionError'>
# exception class name : ZeroDivisionError

# %%
try:
    print(10/'two') # <----------------------------
except BaseException as e:
    print(f'description of exception : {e}')
    print(f'type of exception : {type(e)}')
    print(f'exception class : {e.__class__}')
    print(f'exception class name : {e.__class__.__name__}')
# Out:
# description of exception : unsupported operand type(s) for /: 'int' and 'str'
# type of exception : <class 'TypeError'>
# exception class : <class 'TypeError'>
# exception class name : TypeError

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>try with multiple except blocks</title>
# </head>
# <body>
#     <h1>try with multiple except blocks</h1>
#     <p>The way of handling an exception is varied from exception to exception.</p>
#     <p>Hence for every possible exception type, we have to take a separate except block.</p>
#     <p>try with multiple except blocks is possible and recommended to use.</p>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Try with Multiple Except Blocks</title>
# </head>
# <body>
#     <h1>Try with Multiple Except Blocks</h1>
#     <pre>
# try:
#     .....
#     .....
# except <span style="color:red;">ZeroDivisionError</span>:
#     perform alternative arithmetic operations
# except <span style="color:red;">FileNotFoundError</span>:
#     use <span style="color:blue;">local</span> file instead of remote file
#     </pre>
#     <p>If try with multiple except blocks available, then based on raised exception the corresponding except block will be executed.</p>
# </body>
# </html>

# %%
try:
    print(10/0) 
    
except ZeroDivisionError:
    print('ZeroDivisionError')
    
except ArithmeticError:
    print('ArithmeticError')
# Out:
# ZeroDivisionError

# %%
try:
    print(10/0) 
       
except ArithmeticError:  #<----------------- order is important ,it is baseclass of ZeroDivisionError 
    print('ArithmeticError')

except ZeroDivisionError:
    print('ZeroDivisionError')
# Out:
# ArithmeticError

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Default Except Block</title>
# </head>
# <body>
#     <h1>Default except block</h1>
#     <ul>
#         <li>
#             If default except block is defined then compulsory it must be last except block,
#             otherwise we will get <b>SyntaxError</b>.
#         </li>
#         <li>
#             This restriction is applicable only for default except block but not for normal
#             except blocks. i.e., normal except blocks can be in any order.
#         </li>
#     </ul>
# </body>
# </html>

# %%
try:
    x = int(input('Enter First Number: '))
    y = int(input('Enter Second Number: '))
    print(x / y)
except ZeroDivisionError:
    print('ZeroDivisionError: cannot divide by zero')
except ValueError:
    print('ValueError: please provide valid numeric input only')
except: # this is the default except block to handle all types of exceptions ,and it can be used at last 
    print(f'Default Except: {e}')
# Out:
# ValueError: please provide valid numeric input only

# %%
try:
    x = int(input('Enter First Number: '))
    y = int(input('Enter Second Number: '))
    print(x / y)
    
except: #<---------------------
    print(f'Default Except: {e}')

except ZeroDivisionError:
    print('ZeroDivisionError: cannot divide by zero')
except ValueError:
    print('ValueError: please provide valid numeric input only')
# Out:
#   File "/tmp/ipykernel_2459503/1420480854.py", line 4
#     print(x / y)
#     ^
# SyntaxError: default 'except:' must be last

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Possible Combinations of Except Blocks</title>
# </head>
# <body>
#     <h1>Various possible combinations of except blocks</h1>
#     <ol>
#         <li>except ZeroDivisionError:</li>
#         <li>except (ZeroDivisionError):</li>
#         <li>except ZeroDivisionError as msg:</li>
#         <li>except (ZeroDivisionError) as msg:</li>
#         <li>except (ZeroDivisionError, ValueError):</li>
#         <li>except (ZeroDivisionError, ValueError) as msg:</li>
#         <li>except:</li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Various Possible Combinations of Except Blocks</title>
# </head>
# <body>
#     <h1>Various Possible Combinations of Except Blocks</h1>
#     <ol>
#         <li>If an except block is defined for only one exception, then parentheses are optional. If multiple exceptions are present, then parentheses are mandatory.</li>
#         <li>If we use parentheses, then <code>as</code> must be outside of the parentheses only.</li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Various possible combinations of except blocks</title>
# </head>
# <body>
#     <h1>Various possible combinations of except blocks</h1>
#     <h2>Invalid combinations:</h2>
#     <ul>
#         <li>except (ZeroDivisionError as msg)</li>
#         <li>except ZeroDivisionError,ValueError:</li>
#         <li>except (ZeroDivisionError,ValueError as msg):</li>
#     </ul>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>os._exit(0) vs finally block</title>
# </head>
# <body>
#     <h1>os._exit(0) vs finally block</h1>
#     <p>There is only one situation where the finally block won't be executed, i.e., whenever we are using os._exit(0).</p>
#     <p>Whenever we are using os._exit(0), the Python Virtual Machine itself will be shut down. In this particular case, the finally block won't be executed.</p>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>os._exit(0)</title>
# </head>
# <body>
#     <h1>os._exit(0)</h1>
#     <pre>
# os._exit(0)
#
# - Here zero represents status code.
# - zero means normal termination
# - non-zero means abnormal termination.
# - This status code internally used by PVM.
# - Whether it is zero or non-zero there is difference in the result of the program.
#     </pre>
# </body>
# </html>

# %%
import os 

try:
    print('try')
    os._exit(0)    # it is stopping the pvm explicitly ,output will be only : try 
except ZeroDivisionError:  
    print('except')
finally:
    print('finally')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os 

try:
    print('try')
    os._exit(1000)    # it is stopping the pvm explicitly ,output will be only : try 
except ZeroDivisionError:  
    print('except')
finally:
    print('finally')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ![m](attachment:image.png)

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>finally block vs Destructor</title>
# </head>
# <body>
#     <h1>finally block vs Destructor</h1>
#     <p>finally block meant for maintaining cleanup code.</p>
#     <p>Destructor meant for maintaining cleanup code.</p>
#     <p>Seems to be both are same,</p>
#     <p>where is the difference??????</p>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# </head>
# <body>
#     <p>finally block meant for cleanup activities related to try block. i.e whatever resources we opened as the part of try block will be closed inside finally block.</p>
#     <p>Destructor meant for cleanup activities related to object. What ever resources associated with the object should be deallocated inside destructor, which will be executed before destroying object.</p>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Nested try-except-finally blocks</title>
#
# </head>
# <body>
#     <h1>Nested try-except-finally blocks</h1>
#     <p>We can take <strong>try-except-finally</strong> blocks inside <strong>try</strong> or <strong>except</strong> or <strong>finally</strong>. Hence nesting of try-except-finally blocks is possible.</p>
#     <p>General risky code we have to take inside the outer try block and too much risky code we have to take inside the inner try block.</p>
#     <p>Inside the inner try block, if an exception is raised, then the inner except block is responsible to handle it. If it is unable to handle it, then the outer except block is responsible to handle it.</p>
# </body>
# </html>

# %%
try:
    print('Outer try block')
    try:
        print('Inner try block')
    except ZeroDivisionError:
        print('Inner except block')
    finally:
        print('Inner finally block')
except:
    print('Outer except block')
finally:
    print('Outer finally block')
# Out:
# Outer try block
# Inner try block
# Inner finally block
# Outer finally block

# %%
try:
    print('Outer try block')
    try:
        print('Inner try block')
        print(10/0) # <------------
    except ZeroDivisionError:
        print('Inner except block')
    finally:
        print('Inner finally block')
except:
    print('Outer except block')
finally:
    print('Outer finally block')
# Out:
# Outer try block
# Inner try block
# Inner except block
# Inner finally block
# Outer finally block

# %%
try:
    print('Outer try block')
    try:
        print('Inner try block')
        print(10/0) 
    except ValueError: # <------------
        print('Inner except block')
    finally:
        print('Inner finally block')
except:
    print('Outer except block')
finally:
    print('Outer finally block')
# Out:
# Outer try block
# Inner try block
# Inner finally block
# Outer except block
# Outer finally block

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Try-Finally Explanation</title>
# </head>
# <body>
#     <h2>Try-Finally Explanation</h2>
#     <p>
#         <strong>If the control not entered in the try block, then corresponding finally block won't be executed.</strong>
#     </p>
#     <p>
#         <strong>Once control entered in the try block, compulsory the corresponding finally block will be executed.</strong>
#     </p>
# </body>
# </html>

# %%
try:
    print(10/0) # <------------
    print('Outer try block')
    try:
        print('Inner try block')
         
    except ValueError: 
        print('Inner except block')
    finally:
        print('Inner finally block')
except:
    print('Outer except block')
finally:
    print('Outer finally block')

# %% [markdown]
# ## 15th,April 2020

# %% [markdown]
# ## Error:
# - Error is an illegal operation performed by the
# programmer/user which results in abnormal working of
# the program.

# %% [markdown]
# ## Error Types:
# - 1. Syntax Error or Parsing Error or Compilation Error
# - 2. Logical Error
# - 3. Run-time Error or Exception

# %%
# Ex. of Syntax Error:
print("Start")
print("Welcome to class" #Syntax Error
print("End")
# Out:
#   File "<ipython-input-1-ebdbb86c23d4>", line 4
#     print("End")
#         ^
# SyntaxError: invalid syntax

# %%
# We can correct syntax error by reviewing the syntax.

# Ex. of Logical Error:
print("Start")
n= int(input("Enter no.: "))
if n%2==0:
    print(n,"is odd") # Logical Error
else:
    print(n,"is even")
print("End")
# Out:
# Start
# Enter no.: 5
# 5 is even
# End

# %%
# We can correct logical error by reviewing the logic.

# Ex. of Runtime Error:
print("Start")
nr= int(input("Enter nr.: "))
dr= int(input("Enter dr.: "))
div=nr/dr
print(div)
print("End")
# Out:
# Start
# Enter nr.: 5
# Enter dr.: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-d862e55517ce> in <module>
#       5 nr= int(input("Enter nr.: "))
#       6 dr= int(input("Enter dr.: "))
# ----> 7 div=nr/dr
#       8 print(div)
#       9 print("End")
#
# ZeroDivisionError: division by zero

# %%
# We can handle run-time error using Exception handling technique.

# %% [markdown]
# ## Exceptions:
# - Errors detected during execution are called exceptions.
# - An exception can be defined as an abnormal condition in
# a program resulting in the disruption in the flow of the
# program.
# - Whenever an exception occurs, the program halts the
# execution, and thus the further code is not executed.
# Therefore, an exception is the error which python script
# is unable to tackle completely.

# %% [markdown]
# ## Handle Exception:
# - Python provides us with the way to handle the Exception
# so that the other part of the code can be executed without
# any disruption.
# - However, if we do not handle the Exception, the PVM handles
# the Exception but then it doesn't execute all the code
# that exists after the statement which Raised Exception.

# %%
# Examples of Exception:
print(1/0) #ZeroDivisionError
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-f5dbda1b5d6d> in <module>
#       1 # Examples of Exception:
# ----> 2 print(1/0) #ZeroDivisionError
#
# ZeroDivisionError: division by zero

# %%
print(x) #NameError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-75ec1dd71d27> in <module>
# ----> 1 print(x) #NameError
#
# NameError: name 'x' is not defined

# %%
marks=[50,60,40]
print(marks[6]) #IndexError
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-3fda52f6ae4b> in <module>
#       1 marks=[50,60,40]
# ----> 2 print(marks[6]) #IndexError
#
# IndexError: list index out of range

# %%
open('error.txt') #FileNotFoundError
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-936d701335f6> in <module>
# ----> 1 open('error.txt') #FileNotFoundError
#
# FileNotFoundError: [Errno 2] No such file or directory: 'error.txt'

# %%
n= int(input("Enter no: ")) #ValueError
# Out:
# Enter no: hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a400f4c87d58> in <module>
# ----> 1 n= int(input("Enter no: ")) #ValueError
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
print('four'+2) #TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ac31540f6592> in <module>
# ----> 1 print('four'+2) #TypeError
#
# TypeError: can only concatenate str (not "int") to str

# %%
d={}
print(d['name']) #KeyError
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-578fd26dd12a> in <module>
#       1 d={}
# ----> 2 print(d['name']) #KeyError
#
# KeyError: 'name'

# %% [markdown]
# ## try-except-else-finally statement
# - Syntax:
# - try:
# -     block of code  #doubtful code
# - except Exception_class1:
# -     block of code  #executes if exception occurs in the try block
# - except Exception_class2:
# -     block of code  #executes if first except block was unable to handled the exception
# - else:
# -     block of code #executes only if no exception occurs in the try block
# - finally:
# -     block of code  #will always be executed
# - other code

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>else block with try-except-finally</title>
# </head>
# <body>
#     <h1>else block with try-except-finally</h1>
#     <h2>if-else:</h2>
#     <p>If condition is false then only else will be executed.</p>
#     <h2>for-else:</h2>
#     <p>If loop executed without break then only else will be executed.</p>
#     <h2>while-else:</h2>
#     <p>If loop executed without break then only else will be executed.</p>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Else Block with Try-Except-Finally</title>
# </head>
# <body>
#     <pre>
#         try:
#             Risky code
#         except:
#             Handling code
#             will be executed <strong>if an exception inside try</strong>
#         else:
#             will be executed <strong>if there is no exception inside try</strong>
#         finally:
#             cleanup code
#             will be executed <strong>whether exception raised or not raised and handled or not handled</strong>.
#     </pre>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Else Block with Try-Except-Finally</title>
# </head>
# <body>
#     <ul>
#         <li>There is no chance of executing both <strong>except</strong> and <strong>else</strong> simultaneously.</li>
#         <li>If we want to take <strong>else</strong> block, compulsory <strong>except</strong> block should be there. i.e., <strong>else</strong> without <strong>except</strong> block is always invalid.</li>
#     </ul>
#     <p><strong>SyntaxError:</strong> invalid syntax</p>
# </body>
# </html>

# %%
f = None
try:
    f = open('abc.txt', 'r')
except:
    print('Some problem while locating and opening the file')
else:
    print('File opened successfully')
    print('The data present in the file is:')
    print('#' * 30)
    print(f.read())
finally:
    if f is not None:
        f.close()
# Out:
# File opened successfully
# The data present in the file is:
# ##############################
# line-1
# line-2
# line-3
# line-4
# line-5

# %%
# this is valid 

try:
    print('try') 
finally:
    print('finally block')
# Out:
# try
# finally block

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Try-Except-Else-Finally Combinations</title>
# </head>
# <body>
#     <h1>Various Possible Combinations of <code>try-except-else-finally</code></h1>
#     <ol>
#         <li>
#             <strong>Whenever we are writing a <code>try</code> block, it is compulsory to write either an <code>except</code> or a <code>finally</code> block.</strong><br>
#             <em>i.e., <code>try</code> without <code>except</code> or <code>finally</code> is always invalid.</em>
#         </li>
#         <li>
#             <strong>Whenever we are writing an <code>except</code> block, a <code>try</code> block is compulsory.</strong><br>
#             <em>i.e., <code>except</code> without <code>try</code> is always invalid.</em>
#         </li>
#         <li>
#             <strong>Whenever we are writing a <code>finally</code> block, a <code>try</code> block is compulsory.</strong><br>
#             <em>i.e., <code>finally</code> without <code>try</code> is always invalid.</em>
#         </li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Try-Except-Else-Finally Rules</title>
# </head>
# <body>
#     <ol start="4">
#         <li>
#             <strong>Whenever we are writing an <code>else</code> block, a compulsory <code>except</code> block should be there.</strong><br>
#             <em>i.e., <code>else</code> without <code>except</code> is always invalid.</em>
#         </li>
#         <li>
#             <strong>We can write multiple <code>except</code> blocks for the same <code>try</code>,</strong><br>
#             but we cannot write multiple <code>else</code> blocks or multiple <code>finally</code> blocks.
#         </li>
#         <li>
#             <strong>In <code>try-except-else-finally</code>, the order is important.</strong>
#         </li>
#         <li>
#             <strong>We can write <code>try-except-else-finally</code> inside <code>try</code>, <code>except</code>, <code>else</code>, and <code>finally</code> blocks.</strong><br>
#             <em>Hence nesting of <code>try-except-else-finally</code> is always possible.</em>
#         </li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Types of Exceptions</title>
# </head>
# <body>
#     <h1>Types of Exceptions</h1>
#     <ol>
#         <li>Predefined Exceptions</li>
#         <li>User Defined Exceptions</li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Predefined Exceptions</title>
# </head>
# <body>
#     <p>Also known inbuilt exceptions or PVM Exceptions.</p>
#     <p>These will be raised automatically by Python Virtual Machine whenever a particular event occurs.</p>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Predefined Exceptions</title>
# </head>
# <body>
#     <h1>1. Predefined Exceptions</h1>
#     <p><strong>eg1:</strong> Whenever we are trying to perform division by zero, automatically python will raise ZeroDivisionError.</p>
#     <pre>
#         print(10/0)  # ZeroDivisionError
#     </pre>
#     <p><strong>eg-2:</strong> Whenever we are trying to convert str value to int type and string does not contain int value then we will get ValueError automatically.</p>
#     <pre>
#         x=int('ten')  # ValueError
#     </pre>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>User Defined Exceptions</title>
# </head>
# <body>
#     <h2>2. User Defined Exceptions</h2>
#     <p>Also known as Customized Exceptions or Programmatic Exceptions.</p>
#     <p>Sometimes we have to define and raise exceptions explicitly to indicate that something goes wrong, such type of exceptions are called user defined exceptions or Customized Exceptions or Programmatic Exceptions.</p>
#     <p>Programmer is responsible to define these exceptions and Python Virtual Machine not having any idea about these. Hence we have to raise explicitly based on our requirement by using 'raise' keyword.</p>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Customized Exceptions in Python</title>
# </head>
# <body>
#     <h1>How to define and raise Customized Exceptions</h1>
#     <p>Every exception in Python is a class, and it should be a child class of BaseException.</p>
#     <pre>
# class NameofException(PredefinedException):
#     def __init__(self, msg):
#         self.msg = msg
#     </pre>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>How to define and raise Customized Exceptions</title>
# </head>
# <body>
#     <pre>
#         <code>
# class TooYoungException(Exception):
#     def __init__(self, msg):
#         self.msg = msg
#         </code>
#     </pre>
#     <p>TooYoungException is our exception class name and it is the child class of Exception.</p>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Customized Exceptions</title>
# </head>
# <body>
#     <p>We can raise exception by using <strong>raise</strong> keyword.</p>
#     <p><code>raise TooYoungException('message')</code></p>
# </body>
# </html>

# %%
class TooYoungException(Exception):
    
    def __init__(self,msg):
        self.msg = msg 
        
class TooOldException(Exception):
    
    def __init__(self,msg):
        self.msg = msg 


age = int(input('Enter the age : ')) 

if age > 60:
    raise TooYoungException('Please wait some more time, definitely you will get best match')    
elif age < 18:
    raise TooOldException('Your age already crossed marriage age, no chance of getting marriage')
else:
    print('You will get match details soon by email!!!')
# Out:
# You will get match details soon by email!!!

# %% [markdown]
# # Summary:
# - 1) The try block lets you test a block of code for
# errors.
# - 2) The except block lets you handle the error.
# We can declare multiple except statement.
# - 3) The else block run if no exception occurs.
# - 4) The finally block lets you execute code, regardless(परवाह किए बिना)
# of the result of the try and except blocks.

# %%
# Handling ZeroDivisionError:
print("Start")
nr= int(input("Enter nr.: "))
dr= int(input("Enter dr.: "))
try:
    div=nr/dr #Doubtful code
    print(div)
except ZeroDivisionError as e:#ZeroDivisionError: integer division or modulo by zero
    print(e)
print("End")
# Out:
# Start
# Enter nr.: 1
# Enter dr.: 0
# division by zero
# End

# %%
# Handle multiple Exceptions:
print("Start")
try:
    nr= int(input("Enter nr.: "))
    dr= int(input("Enter dr.: "))
    div=nr/dr
    print(div)
except ValueError as e:
    print(e)
except ZeroDivisionError as e:
    print(e)
print("End")
# Out:
# Start
# Enter nr.: 1
# Enter dr.: nj
# invalid literal for int() with base 10: 'nj'
# End

# %%
# Handle Multiple Error using single except statement:
print("Start")
try:
    nr= int(input("Enter nr.: "))
    dr= int(input("Enter dr.: "))
    div=nr/dr
    print(div)
except (ValueError,ZeroDivisionError) as e:
    print(e)
print("End")
# Out:
# Start
# Enter nr.: fd
# invalid literal for int() with base 10: 'fd'
# End

# %%
# Handle Exceptions with 'Exception' class
print("Start")
try:
    nr= int(input("Enter nr.: "))
    dr= int(input("Enter dr.: "))
    div=nr/dr
    print(div)
except Exception as e:
    print(e)
print("End")
# Out:
# Start
# Enter nr.: @
# invalid literal for int() with base 10: '@'
# End

# %%
# Handle Exception Gracefully:
print("Start")
try:
    nr= int(input("Enter nr.: "))
    dr= int(input("Enter dr.: "))
    div=nr/dr
    print(div)
except (ValueError,ZeroDivisionError):
    print("Enter values correctly")
print("End")
# Out:
# Start
# Enter nr.: h
# Enter values correctly
# End

# %%
# Using else-finally statement:
print("Start")
try:
    nr= int(input("Enter nr.: "))
    dr= int(input("Enter dr.: "))
    div=nr/dr
    print(div)
except (ValueError,ZeroDivisionError):
    print("Enter values correctly")
else:
    print("Else block executed")
finally:
    print("finally block executed")
# Out:
# Start
# Enter nr.: 2
# Enter dr.: 8
# 0.25
# Else block executed
# finally block executed

# %% [markdown]
# ## Raising Exception:
# - In python we can raise an exception explicitely using
# - 'raise' keyword.
# - The raise statement allows the programmer to force a
# - specific exception to occur.
# - Syntax:
# - raise ExceptionClass(message)

# %%
# 'raise' exception for age less than 0.
def checkAge(n):
    if n<=0:
        raise ZeroDivisionError('Age can\'t be less than 0')
    elif isinstance(n,float):
        raise ValueError('Age can\'t be in float')
    
try:
    age=int(input("Enter age: "))
    checkAge(age)
except (ZeroDivisionError,ValueError) as e:
    print(e)
    age=0
finally:
    print('Age is',age)
# Out:
# Enter age: 9.0
# invalid literal for int() with base 10: '9.0'
# Age is 0

# %%
def age_detector(n):
    if n<=0:
        raise ZeroDivisionError('Age must be greater than zero')
    elif isinstance(n,float):
        raise ValueError('Age can\'t be float')
try:
    age=float(input())
    age_detector(age)
except (ZeroDivisionError,ValueError) as e:
    print(e)
finally:
    print(f'Age is {age}')
# Out:
# 5
# Age can't be float
# Age is 5.0

# %%
# Create Custom Exception class:
class PriceLessThanZero(Exception):
    def __init__(self,msg):
        super().__init__(msg)

def calDisc(n,disc):
    if n<0 or disc<0:
        raise PriceLessThanZero('Price & disc can\'t be less than 0')
    else:
        final= (n-((n*disc)/100))
        return final

print("Billing Counter")
try:
    price=float(input("Enter price: "))
    discount=float(input("Enter discount: "))
    print(calDisc(price,discount))
except PriceLessThanZero as r:
    print(r)
# Out:
# Billing Counter
# Enter price: 30
# Enter discount: 2
# 29.4
